# %% [markdown]
# <a href="https://colab.research.google.com/github/gokulavel/datascience/blob/linear/linear%20regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

df =pd.read_csv('covid_19_india.csv')
grouped =df.groupby('State/UnionTerritory')

# %%
for name,group in grouped:
  print(name)
  print(group)
# Out:
# Andaman and Nicobar Islands
#        Sno      Date      Time  ... Cured  Deaths  Confirmed
# 365    366  26/03/20   6:00 PM  ...     0       0          1
# 392    393  27/03/20  10:00 AM  ...     0       0          1
# 420    421  28/03/20   6:00 PM  ...     0       0          6
# 447    448  29/03/20   7:30 PM  ...     0       0          9
# 474    475  30/03/20   9:30 PM  ...     0       0          9
# ...    ...       ...       ...  ...   ...     ...        ...
# 4286  4287  20/07/20   8:00 AM  ...   145       0        203
# 4321  4322  21/07/20   8:00 AM  ...   152       0        207
# 4356  4357  22/07/20   8:00 AM  ...   159       0        212
# 4391  4392  23/07/20   8:00 AM  ...   163       0        221
# 4426  4427  24/07/20   8:00 AM  ...   170       0        240
#
# [121 rows x 7 columns]
# Andhra Pradesh
#        Sno      Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 121    122  12/03/20  6:00 PM       Andhra Pradesh      0       0          1
# ...

# %%
plt.figure(figsize=(50, 10))
plt.bar(df['State/UnionTerritory'],df['Cured'])
plt.xlabel('States/UnionTerritory')
plt.ylabel('Cured people')
plt.show()

# %%
plt.figure(figsize=(50, 10))
plt.bar(df['State/UnionTerritory'],df['Deaths'])
plt.xlabel('States/UnionTerritory')
plt.ylabel('Deaths')
plt.show()

# %%
plt.figure(figsize=(50, 10))
plt.bar(df['State/UnionTerritory'],df['Confirmed'])
plt.xlabel('States/UnionTerritory')
plt.ylabel('Confirmed')
plt.show()
